# %% [markdown]
# # MILITARY POWER

# %% [markdown]
# This dataset allows you to see the world military rankings in 2020 and numerical status s such as the army, navy, and air force.
#
# In addition, some related data such as population and economy related to military power are also included.

# %% [markdown]
# <img src='https://i.pinimg.com/236x/35/89/07/358907e171ef5ec7e9cef5f962e6809d.jpg' style='display: block; margin-left: auto; margin-right: auto;'>
#
# <a href='https://www.kaggle.com/code/durmusayuksek/world-military-powers-2020-clustering' target= _blank> Can get data from this link

# %%
import pandas as pd
import warnings
import sqlite3
import plotly.express as px
import plotly.io as pio
import plotly.graph_objects as go
from yellowbrick.cluster import KElbowVisualizer
from sklearn.cluster import KMeans, AgglomerativeClustering
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler
import seaborn as sns
from matplotlib import pyplot as plt
pio.templates.default = "plotly_white"
warnings.filterwarnings("ignore")

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
df = pd.read_excel("World military power.xlsx", skiprows=1)

# %%
df.shape
# Out:
# (137, 60)

# %%
df.head()
# Out:
#                 Hungary  0.8215             Hungary.1    47  \
# 0  United Arab Emirates  0.7034  United Arab Emirates   538
# 1               Belarus  0.8179               Belarus   202
# 2              Honduras  2.0943              Honduras    46
# 3                 Egypt  0.1872                 Egypt  1054
# 4               Vietnam  0.3559               Vietnam   293
#
#               Hungary.2   12             Hungary.3   0             Hungary.4  \
# 0  United Arab Emirates   98  United Arab Emirates  20  United Arab Emirates
# 1               Belarus   39               Belarus  68               Belarus
# 2              Honduras    3              Honduras   9              Honduras
# 3                 Egypt  215                 Egypt  88                 Egypt
# 4               Vietnam   77               Vietnam   0               Vietnam
#
#     5             Hungary.5    6             Hungary.6   24  \
# 0  40  United Arab Emirates  145  United Arab Emirates  229
# 1   4               Belarus   28               Belarus   63
# 2  11              Honduras   10              Honduras   12
# 3  59                 Egypt  387                 Egypt  294
# 4  38               Vietnam   36               Vietnam  138
#
#               Hungary.7   8             Hungary.8    30             Hungary.9  \
# 0  United Arab Emirates  30  United Arab Emirates   434  United Arab Emirates
# 1               Belarus  21               Belarus   532               Belarus
# 2              Honduras   0              Honduras    19              Honduras
# 3                 Egypt  81                 Egypt  4295                 Egypt
# 4               Vietnam  25               Vietnam  2615               Vietnam
#
#      944            Hungary.10   0.1            Hungary.11   300  \
# 0   8691  United Arab Emirates   183  United Arab Emirates    76
# 1   1560               Belarus   482               Belarus   228
# 2     92              Honduras     0              Honduras   176
# 3  11700                 Egypt  1139                 Egypt  2189
# 4   2530               Vietnam    70               Vietnam  1000
#
#              Hungary.12   0.2           Unnamed: 26  Unnamed: 27  \
# 0  United Arab Emirates    72  United Arab Emirates         75.0
# 1               Belarus   238               Belarus          0.0
# 2              Honduras     0              Honduras         59.0
# 3                 Egypt  1084                 Egypt        316.0
# 4               Vietnam    85               Vietnam         65.0
#
#             Unnamed: 28  Unnamed: 29           Unnamed: 30  Unnamed: 31  \
# 0  United Arab Emirates          0.0  United Arab Emirates          0.0
# 1                   NaN          NaN                   NaN          NaN
# 2              Honduras          0.0              Honduras          0.0
# 3                 Egypt          2.0                 Egypt          8.0
# 4               Vietnam          0.0               Vietnam          6.0
#
#             Unnamed: 32  Unnamed: 33           Unnamed: 34  Unnamed: 35  \
# 0  United Arab Emirates          0.0  United Arab Emirates          0.0
# 1                   NaN          NaN                   NaN          NaN
# 2              Honduras          0.0              Honduras          0.0
# 3                 Egypt          0.0                 Egypt          7.0
# 4               Vietnam          0.0               Vietnam          9.0
#
#              Hungary.13   2,08,00,00,000            Hungary.14  \
# 0  United Arab Emirates  22,75,50,00,000  United Arab Emirates
# 1               Belarus     62,37,02,800               Belarus
# 2              Honduras     20,50,00,000              Honduras
# 3                 Egypt  11,20,00,00,000                 Egypt
# 4               Vietnam   5,50,00,00,000               Vietnam
#
#    1,38,10,00,00,000            Hungary.15   41            Hungary.16  \
# 0  2,37,60,00,00,000  United Arab Emirates   43  United Arab Emirates
# 1    39,92,00,00,000               Belarus   65               Belarus
# 2     8,62,50,00,000              Honduras  103              Honduras
# 3    77,47,00,00,000                 Egypt   83                 Egypt
# 4    96,58,00,00,000               Vietnam   45               Vietnam
#
#        14000            Hungary.17  1,45,000            Hungary.18  \
# 0  31,74,000  United Arab Emirates  5,75,000  United Arab Emirates
# 1      32000               Belarus  1,90,000               Belarus
# 2          0              Honduras     60000              Honduras
# 3   5,89,400                 Egypt  8,32,000                 Egypt
# 4   2,71,400               Vietnam  5,25,000               Vietnam
#
#        2,51,00,000            Hungary.19    46,18,081            Hungary.20  \
# 0  97,80,00,00,000  United Arab Emirates    58,20,789  United Arab Emirates
# 1     19,80,00,000               Belarus    49,82,905               Belarus
# 2                0              Honduras    41,04,696              Honduras
# 3   4,40,00,00,000                 Egypt  4,29,46,553                 Egypt
# 4   4,40,00,00,000               Vietnam  5,10,43,216               Vietnam
#
#      98,25,704            Hungary.21   1,03,000           Unnamed: 54  \
# 0    97,01,315  United Arab Emirates      83600  United Arab Emirates
# 1    95,27,543               Belarus   2,07,600                   NaN
# 2    91,82,766              Honduras   1,12,090              Honduras
# 3  9,94,13,317                 Egypt  10,01,450                 Egypt
# 4  9,70,40,334               Vietnam   3,31,210               Vietnam
#
#   Unnamed: 55            Hungary.22   1622            Hungary.23    2106
# 0        1318  United Arab Emirates      0  United Arab Emirates  1066.0
# 1         NaN               Belarus   2500               Belarus  3599.0
# 2         832              Honduras    465              Honduras  1575.0
# 3        2450                 Egypt   3500                 Egypt  2612.0
# 4        3444               Vietnam  17702               Vietnam  4616.0

# %%
# rename Military Strength column as Countries

df.rename(columns={"Military Strength": "Countries"}, inplace=True)

# %%
df.head()
# Out:
#                 Hungary  0.8215             Hungary.1    47  \
# 0  United Arab Emirates  0.7034  United Arab Emirates   538
# 1               Belarus  0.8179               Belarus   202
# 2              Honduras  2.0943              Honduras    46
# 3                 Egypt  0.1872                 Egypt  1054
# 4               Vietnam  0.3559               Vietnam   293
#
#               Hungary.2   12             Hungary.3   0             Hungary.4  \
# 0  United Arab Emirates   98  United Arab Emirates  20  United Arab Emirates
# 1               Belarus   39               Belarus  68               Belarus
# 2              Honduras    3              Honduras   9              Honduras
# 3                 Egypt  215                 Egypt  88                 Egypt
# 4               Vietnam   77               Vietnam   0               Vietnam
#
#     5             Hungary.5    6             Hungary.6   24  \
# 0  40  United Arab Emirates  145  United Arab Emirates  229
# 1   4               Belarus   28               Belarus   63
# 2  11              Honduras   10              Honduras   12
# 3  59                 Egypt  387                 Egypt  294
# 4  38               Vietnam   36               Vietnam  138
#
#               Hungary.7   8             Hungary.8    30             Hungary.9  \
# 0  United Arab Emirates  30  United Arab Emirates   434  United Arab Emirates
# 1               Belarus  21               Belarus   532               Belarus
# 2              Honduras   0              Honduras    19              Honduras
# 3                 Egypt  81                 Egypt  4295                 Egypt
# 4               Vietnam  25               Vietnam  2615               Vietnam
#
#      944            Hungary.10   0.1            Hungary.11   300  \
# 0   8691  United Arab Emirates   183  United Arab Emirates    76
# 1   1560               Belarus   482               Belarus   228
# 2     92              Honduras     0              Honduras   176
# 3  11700                 Egypt  1139                 Egypt  2189
# 4   2530               Vietnam    70               Vietnam  1000
#
#              Hungary.12   0.2           Unnamed: 26  Unnamed: 27  \
# 0  United Arab Emirates    72  United Arab Emirates         75.0
# 1               Belarus   238               Belarus          0.0
# 2              Honduras     0              Honduras         59.0
# 3                 Egypt  1084                 Egypt        316.0
# 4               Vietnam    85               Vietnam         65.0
#
#             Unnamed: 28  Unnamed: 29           Unnamed: 30  Unnamed: 31  \
# 0  United Arab Emirates          0.0  United Arab Emirates          0.0
# 1                   NaN          NaN                   NaN          NaN
# 2              Honduras          0.0              Honduras          0.0
# 3                 Egypt          2.0                 Egypt          8.0
# 4               Vietnam          0.0               Vietnam          6.0
#
#             Unnamed: 32  Unnamed: 33           Unnamed: 34  Unnamed: 35  \
# 0  United Arab Emirates          0.0  United Arab Emirates          0.0
# 1                   NaN          NaN                   NaN          NaN
# 2              Honduras          0.0              Honduras          0.0
# 3                 Egypt          0.0                 Egypt          7.0
# 4               Vietnam          0.0               Vietnam          9.0
#
#              Hungary.13   2,08,00,00,000            Hungary.14  \
# 0  United Arab Emirates  22,75,50,00,000  United Arab Emirates
# 1               Belarus     62,37,02,800               Belarus
# 2              Honduras     20,50,00,000              Honduras
# 3                 Egypt  11,20,00,00,000                 Egypt
# 4               Vietnam   5,50,00,00,000               Vietnam
#
#    1,38,10,00,00,000            Hungary.15   41            Hungary.16  \
# 0  2,37,60,00,00,000  United Arab Emirates   43  United Arab Emirates
# 1    39,92,00,00,000               Belarus   65               Belarus
# 2     8,62,50,00,000              Honduras  103              Honduras
# 3    77,47,00,00,000                 Egypt   83                 Egypt
# 4    96,58,00,00,000               Vietnam   45               Vietnam
#
#        14000            Hungary.17  1,45,000            Hungary.18  \
# 0  31,74,000  United Arab Emirates  5,75,000  United Arab Emirates
# 1      32000               Belarus  1,90,000               Belarus
# 2          0              Honduras     60000              Honduras
# 3   5,89,400                 Egypt  8,32,000                 Egypt
# 4   2,71,400               Vietnam  5,25,000               Vietnam
#
#        2,51,00,000            Hungary.19    46,18,081            Hungary.20  \
# 0  97,80,00,00,000  United Arab Emirates    58,20,789  United Arab Emirates
# 1     19,80,00,000               Belarus    49,82,905               Belarus
# 2                0              Honduras    41,04,696              Honduras
# 3   4,40,00,00,000                 Egypt  4,29,46,553                 Egypt
# 4   4,40,00,00,000               Vietnam  5,10,43,216               Vietnam
#
#      98,25,704            Hungary.21   1,03,000           Unnamed: 54  \
# 0    97,01,315  United Arab Emirates      83600  United Arab Emirates
# 1    95,27,543               Belarus   2,07,600                   NaN
# 2    91,82,766              Honduras   1,12,090              Honduras
# 3  9,94,13,317                 Egypt  10,01,450                 Egypt
# 4  9,70,40,334               Vietnam   3,31,210               Vietnam
#
#   Unnamed: 55            Hungary.22   1622            Hungary.23    2106
# 0        1318  United Arab Emirates      0  United Arab Emirates  1066.0
# 1         NaN               Belarus   2500               Belarus  3599.0
# 2         832              Honduras    465              Honduras  1575.0
# 3        2450                 Egypt   3500                 Egypt  2612.0
# 4        3444               Vietnam  17702               Vietnam  4616.0

# %%
# Çift indeksli kolonları (0 hariç) silme
columns_to_drop = [col for i, col in enumerate(df.columns) if i % 2 == 0 and i != 0]
df.drop(columns=columns_to_drop, inplace=True)

# %%
df.head()
# Out:
#                 Hungary  0.8215    47   12   0   5    6   24   8    30    944  \
# 0  United Arab Emirates  0.7034   538   98  20  40  145  229  30   434   8691
# 1               Belarus  0.8179   202   39  68   4   28   63  21   532   1560
# 2              Honduras  2.0943    46    3   9  11   10   12   0    19     92
# 3                 Egypt  0.1872  1054  215  88  59  387  294  81  4295  11700
# 4               Vietnam  0.3559   293   77   0  38   36  138  25  2615   2530
#
#     0.1   300   0.2  Unnamed: 27  Unnamed: 29  Unnamed: 31  Unnamed: 33  \
# 0   183    76    72         75.0          0.0          0.0          0.0
# 1   482   228   238          0.0          NaN          NaN          NaN
# 2     0   176     0         59.0          0.0          0.0          0.0
# 3  1139  2189  1084        316.0          2.0          8.0          0.0
# 4    70  1000    85         65.0          0.0          6.0          0.0
#
#    Unnamed: 35   2,08,00,00,000  1,38,10,00,00,000   41      14000  1,45,000  \
# 0          0.0  22,75,50,00,000  2,37,60,00,00,000   43  31,74,000  5,75,000
# 1          NaN     62,37,02,800    39,92,00,00,000   65      32000  1,90,000
# 2          0.0     20,50,00,000     8,62,50,00,000  103          0     60000
# 3          7.0  11,20,00,00,000    77,47,00,00,000   83   5,89,400  8,32,000
# 4          9.0   5,50,00,00,000    96,58,00,00,000   45   2,71,400  5,25,000
#
#        2,51,00,000    46,18,081    98,25,704   1,03,000 Unnamed: 55   1622  \
# 0  97,80,00,00,000    58,20,789    97,01,315      83600        1318      0
# 1     19,80,00,000    49,82,905    95,27,543   2,07,600         NaN   2500
# 2                0    41,04,696    91,82,766   1,12,090         832    465
# 3   4,40,00,00,000  4,29,46,553  9,94,13,317  10,01,450        2450   3500
# 4   4,40,00,00,000  5,10,43,216  9,70,40,334   3,31,210        3444  17702
#
#      2106
# 0  1066.0
# 1  3599.0
# 2  1575.0
# 3  2612.0
# 4  4616.0

# %%
df.shape
# Out:
# (137, 31)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137 entries, 0 to 136
# Data columns (total 31 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Hungary            137 non-null    object
#  1   0.8215             137 non-null    float64
#  2   47                 137 non-null    int64
#  3   12                 137 non-null    int64
#  4   0                  137 non-null    int64
#  5   5                  137 non-null    int64
#  6   6                  137 non-null    int64
#  7   24                 137 non-null    int64
#  8   8                  137 non-null    int64
#  9   30                 137 non-null    int64
#  10  944                137 non-null    int64
#  11  0.1                137 non-null    int64
#  12  300                137 non-null    int64
#  13  0.2                137 non-null    int64
#  14  Unnamed: 27        124 non-null    float64
#  15  Unnamed: 29        115 non-null    float64
#  16  Unnamed: 31        115 non-null    float64
#  17  Unnamed: 33        115 non-null    float64
#  18  Unnamed: 35        115 non-null    float64
#  19  2,08,00,00,000     137 non-null    object
#  20  1,38,10,00,00,000  137 non-null    object
#  21  41                 137 non-null    int64
#  22  14000              137 non-null    object
#  23  1,45,000           137 non-null    object
#  24  2,51,00,000        137 non-null    object
#  25  46,18,081          137 non-null    object
#  26  98,25,704          137 non-null    object
#  27  1,03,000           137 non-null    object
#  28  Unnamed: 55        109 non-null    object
#  29  1622               137 non-null    object
#  30  2106               128 non-null    float64
# dtypes: float64(7), int64(13), object(11)
# memory usage: 33.3+ KB

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Unnamed: 55          28
# Unnamed: 29          22
# Unnamed: 35          22
# Unnamed: 33          22
# Unnamed: 31          22
# Unnamed: 27          13
# 2106                  9
# 24                    0
# 8                     0
# 1622                  0
# 47                    0
# 1,03,000              0
# 98,25,704             0
# 46,18,081             0
# 2,51,00,000           0
# 1,45,000              0
# 14000                 0
# 41                    0
# 1,38,10,00,00,000     0
# 2,08,00,00,000        0
# 12                    0
# 0                     0
# 5                     0
# 0.8215                0
# 6                     0
# 0.2                   0
# 300                   0
# 0.1                   0
# 944                   0
# 30                    0
# Hungary               0
# dtype: int64

# %%
for c in df.columns:
    if c == 'Countries':
        continue
    if df[c].dtype != 'object':
        continue
    
    df[c] = df[c].astype(str)
    df[c] = df[c].apply(lambda x: 0 if x == "nan" else x)
    df[c] = df[c].str.replace(',', '')
    df[c] = df[c].str.replace('.', '')
    df[c] = pd.to_numeric(df[c])
    df[c] = df[c].apply(lambda x: 0 if x is None else x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File lib.pyx:2374, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "United Arab Emirates"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 11
#       9 df[c] = df[c].str.replace(',', '')
#      10 df[c] = df[c].str.replace('.', '')
# ---> 11 df[c] = pd.to_numeric(df[c])
#      12 df[c] = df[c].apply(lambda x: 0 if x is None else x)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\tools\numeric.py:222, in to_numeric(arg, errors, downcast, dtype_backend)
#     220 coerce_numeric = errors not in ("ignore", "raise")
#     221 try:
# --> 222     values, new_mask = lib.maybe_convert_numeric(  # type: ignore[call-overload]  # noqa: E501
#     223         values,
#     224         set(),
#     225         coerce_numeric=coerce_numeric,
#     226         convert_to_masked_nullable=dtype_backend is not lib.no_default
#     227         or isinstance(values_dtype, StringDtype)
#     228         and not values_dtype.storage == "pyarrow_numpy",
#     229     )
#     230 except (ValueError, TypeError):
#     231     if errors == "raise":
#
# File lib.pyx:2416, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "United Arab Emirates" at position 0

# %%
df.isnull().sum().sort_values(ascending=False)

# %%
# fill missings by 0
for col in df.columns:
    if col == 'Countries':
        continue
    df[col] = df[col].fillna(0)

# %% [markdown]
# ### Modelling

# %%
x = df.drop("Countries", axis=1)

vis = KElbowVisualizer(KMeans(), k=(2, 10))

vis.fit(x)

vis.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[142], line 5
#       1 x = df.drop("Countries", axis=1)
#       3 vis = KElbowVisualizer(KMeans(), k=(2, 10))
# ----> 5 vis.fit(x)
#       7 vis.show()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\yellowbrick\cluster\elbow.py:339, in KElbowVisualizer.fit(self, X, y, **kwargs)
#     337 # Set the k value and fit the model
#     338 self.estimator.set_params(n_clusters=k)
# --> 339 self.estimator.fit(X, **kwargs)
#     341 # Append the time and score to our plottable metrics
#     342 self.k_timers_.append(time.time() - start)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1417, in KMeans.fit(self, X, y, sample_weight)
#    1390 """Compute k-means clustering.
#    1391
#    1392 Parameters
#    (...)
#    1413     Fitted estimator.
#    1414 """
#    1415 self._validate_params()
# -> 1417 X = self._validate_data(
#    1418     X,
#    1419     accept_sparse="csr",
#    1420     dtype=[np.float64, np.float32],
#    1421     order="C",
#    1422     copy=self.copy_x,
#    1423     accept_large_sparse=False,
#    1424 )
#    1426 self._check_params_vs_input(X)
#    1428 random_state = check_random_state(self.random_state)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:565, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     563     raise ValueError("Validation should be done on X, y or both.")
#     564 elif not no_val_X and no_val_y:
# --> 565     X = check_array(X, input_name="X", **check_params)
#     566     out = X
#     567 elif no_val_X and not no_val_y:
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:921, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     915         raise ValueError(
#     916             "Found array with dim %d. %s expected <= 2."
#     917             % (array.ndim, estimator_name)
#     918         )
#     920     if force_all_finite:
# --> 921         _assert_all_finite(
#     922             array,
#     923             input_name=input_name,
#     924             estimator_name=estimator_name,
#     925             allow_nan=force_all_finite == "allow-nan",
#     926         )
#     928 if ensure_min_samples > 0:
#     929     n_samples = _num_samples(array)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:161, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     144 if estimator_name and input_name == "X" and has_nan_error:
#     145     # Improve the error message on how to handle missing values in
#     146     # scikit-learn.
#     147     msg_err += (
#     148         f"\n{estimator_name} does not accept missing values"
#     149         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     159         "#estimators-that-handle-nan-values"
#     160     )
# --> 161 raise ValueError(msg_err)
#
# ValueError: Input X contains NaN.
# KMeans does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values

# %%
model = KMeans(n_clusters=4, random_state=42)
model = model.fit(x)
pred = model.predict(x)

# %%
x["cluster"] = pred
df["cluster"] = pred
