# %% [markdown]
# # LOAN PREDICTION

# %% [markdown]
# In this project, I will try to design a model with Classification machine learning methods that can make predictions for a financial institution about whether loan customers will be able to pay their loan debts. This dataset is taken from Kaggle.com.

# %% [markdown]
# <img src='https://d28wu8o6itv89t.cloudfront.net/images/Typesofloaninindiapng-1591776023072.png'>
# <br>
# <img src='https://signalscv.s3.us-west-1.amazonaws.com/wp-content/uploads/2020/03/09093452/1-3-750x375.jpg'> <br>
# <br>
# <a href='https://www.kaggle.com/datasets/omkar5/dataset-for-bank-loan-prediction/data' target= _blank> Can get data from this link

# %% [markdown]
# ### Data Dictionary

# %% [markdown]
# The dataset consists of the following fields:<br>
# • **Loan ID**: A unique Identifier for the loan information.<br>
# • **Customer ID**: A unique identifier for the customer. Customers may have more than one loan.<br>
# • **Loan Status**: A categorical variable indicating if the loan was paid back or defaulted.<br>
# • **Current Loan Amount**: This is the loan amount that was either completely paid off, or the amount that was defaulted.<br>
# • **Term**: A categorical variable indicating if it is a short term or long term loan.<br>
# • **Credit Score**: A value between 0 and 800 indicating the riskiness of the borrowers credit history.<br>
# • **Years in current job**: A categorical variable indicating how many years the customer has been in their current job.<br>
# • **Home Ownership**: Categorical variable indicating home ownership. Values are "Rent", "Home Mortgage", and "Own". If the value is OWN, then the customer is a home owner with no mortgage<br>
# • **Annual Income**: The customer's annual income<br>
# • **Purpose**: A description of the purpose of the loan.<br>
# • **Monthly Debt**: The customer's monthly payment for their existing loans<br>
# • **Years of Credit History**: The years since the first entry in the customer’s credit history <br>
# • **Months since last delinquent**: Months since the last loan delinquent payment<br>
# • **Number of Open Accounts**: The total number of open credit cards<br>
# • **Number of Credit Problems**: The number of credit problems in the customer records.<br>
# • **Current Credit Balance**: The current total debt for the customer<br>
# • **Maximum Open Credit**: The maximum credit limit for all credit sources.<br>
# • **Bankruptcies**: The number of bankruptcies<br>
# • **Tax Liens**: The number of tax liens.<br>

# %% [markdown]
# ### Importing of essential packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings("ignore")

pd.set_option("display.max_columns",100)
pd.set_option("display.max_rows",100)

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import BernoulliNB
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# ### Reading data

# %%
df = pd.read_csv('LoansTrainingSet.csv')
# Out:
# C:\Users\Ramazan & Selma\AppData\Local\Temp\ipykernel_26540\3228652955.py:1: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('LoansTrainingSet.csv')

# %% [markdown]
# ### EDA

# %%
df.head()
# Out:
#                                 Loan ID                           Customer ID  \
# 0  000025bb-5694-4cff-b17d-192b1a98ba44  5ebc8bb1-5eb9-4404-b11b-a6eebc401a19
# 1  00002c49-3a29-4bd4-8f67-c8f8fbc1048c  927b388d-2e01-423f-a8dc-f7e42d668f46
# 2  00002d89-27f3-409b-aa76-90834f359a65  defce609-c631-447d-aad6-1270615e89c4
# 3  00005222-b4d8-45a4-ad8c-186057e24233  070bcecb-aae7-4485-a26a-e0403e7bb6c5
# 4  0000757f-a121-41ed-b17b-162e76647c1f  dde79588-12f0-4811-bab0-e2b07f633fcd
#
#   Loan Status  Current Loan Amount        Term  Credit Score  \
# 0  Fully Paid                11520  Short Term         741.0
# 1  Fully Paid                 3441  Short Term         734.0
# 2  Fully Paid                21029  Short Term         747.0
# 3  Fully Paid                18743  Short Term         747.0
# 4  Fully Paid                11731  Short Term         746.0
#
#   Years in current job Home Ownership  Annual Income             Purpose  \
# 0            10+ years  Home Mortgage        33694.0  Debt Consolidation
# 1              4 years  Home Mortgage        42269.0               other
# 2            10+ years  Home Mortgage        90126.0  Debt Consolidation
# 3            10+ years       Own Home        38072.0  Debt Consolidation
# 4              4 years           Rent        50025.0  Debt Consolidation
#
#   Monthly Debt  Years of Credit History  Months since last delinquent  \
# 0      $584.03                     12.3                          41.0
# 1   $1,106.04                      26.3                           NaN
# 2   $1,321.85                      28.8                           NaN
# 3      $751.92                     26.2                           NaN
# 4      $355.18                     11.5                           NaN
#
#    Number of Open Accounts  Number of Credit Problems  Current Credit Balance  \
# 0                       10                          0                    6760
# 1                       17                          0                    6262
# 2                        5                          0                   20967
# 3                        9                          0                   22529
# 4                       12                          0                   17391
#
#   Maximum Open Credit  Bankruptcies  Tax Liens
# 0               16056           0.0        0.0
# 1               19149           0.0        0.0
# 2               28335           0.0        0.0
# 3               43915           0.0        0.0
# 4               37081           0.0        0.0

# %%
df.tail()
# Out:
#                                      Loan ID  \
# 256979  fffef5b7-be99-4666-ac70-2a397d2ee435
# 256980  ffffca93-aa8c-4123-b8ff-7852f6df889a
# 256981  ffffcb2e-e48e-4d2c-a0d6-ed6bce5bfdbe
# 256982  ffffcb2e-e48e-4d2c-a0d6-ed6bce5bfdbe
# 256983  ffffe32e-ed17-459f-9cfd-7b9ee7972933
#
#                                  Customer ID  Loan Status  \
# 256979  7211a8e3-cba4-4132-b939-222eed8a662c   Fully Paid
# 256980  616fef0c-8f09-4327-9b5c-48fcfaa52934   Fully Paid
# 256981  971a6682-183b-4a52-8bce-1d3429ade295  Charged Off
# 256982  971a6682-183b-4a52-8bce-1d3429ade295  Charged Off
# 256983  97281336-1e45-41d2-acb2-263ce56a590e   Fully Paid
#
#         Current Loan Amount        Term  Credit Score Years in current job  \
# 256979                 3911  Short Term           NaN              2 years
# 256980                 5078  Short Term         737.0            10+ years
# 256981                12116  Short Term        7460.0              9 years
# 256982                12116  Short Term         746.0              9 years
# 256983                27902   Long Term         678.0            10+ years
#
#        Home Ownership  Annual Income             Purpose Monthly Debt  \
# 256979           Rent            NaN  Debt Consolidation   $1,706.58
# 256980       Own Home        77186.0  Debt Consolidation   $1,376.47
# 256981  Home Mortgage        52504.0  Debt Consolidation      $297.96
# 256982  Home Mortgage        52504.0  Debt Consolidation      $297.96
# 256983  Home Mortgage       117480.0  Debt Consolidation   $2,525.82
#
#         Years of Credit History  Months since last delinquent  \
# 256979                     19.9                           NaN
# 256980                     19.1                          47.0
# 256981                     15.1                          82.0
# 256982                     15.1                          82.0
# 256983                     18.0                          11.0
#
#         Number of Open Accounts  Number of Credit Problems  \
# 256979                       16                          0
# 256980                        9                          0
# 256981                        8                          0
# 256982                        8                          0
# 256983                       10                          0
#
#         Current Credit Balance Maximum Open Credit  Bankruptcies  Tax Liens
# 256979                   43992               44080           0.0        0.0
# 256980                    1717                9758           0.0        0.0
# 256981                    3315               20090           0.0        0.0
# 256982                    3315               20090           0.0        0.0
# 256983                   28317               62371           0.0        0.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 256984 entries, 0 to 256983
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Loan ID                       256984 non-null  object
#  1   Customer ID                   256984 non-null  object
#  2   Loan Status                   256984 non-null  object
#  3   Current Loan Amount           256984 non-null  int64
#  4   Term                          256984 non-null  object
#  5   Credit Score                  195308 non-null  float64
#  6   Years in current job          245508 non-null  object
#  7   Home Ownership                256984 non-null  object
#  8   Annual Income                 195308 non-null  float64
#  9   Purpose                       256984 non-null  object
#  10  Monthly Debt                  256984 non-null  object
#  11  Years of Credit History       256984 non-null  float64
#  12  Months since last delinquent  116601 non-null  float64
#  13  Number of Open Accounts       256984 non-null  int64
#  14  Number of Credit Problems     256984 non-null  int64
#  15  Current Credit Balance        256984 non-null  int64
#  16  Maximum Open Credit           256984 non-null  object
#  17  Bankruptcies                  256455 non-null  float64
#  18  Tax Liens                     256961 non-null  float64
# dtypes: float64(6), int64(4), object(9)
# memory usage: 37.3+ MB

# %%
df.describe().T
# Out:
#                                  count          mean           std    min  \
# Current Loan Amount           256984.0  1.371331e+07  3.438131e+07  505.0
# Credit Score                  195308.0  1.251116e+03  1.762017e+03  585.0
# Annual Income                 195308.0  7.195272e+04  5.887757e+04    0.0
# Years of Credit History       256984.0  1.829019e+01  7.075747e+00    3.4
# Months since last delinquent  116601.0  3.488145e+01  2.185417e+01    0.0
# Number of Open Accounts       256984.0  1.110627e+01  4.982982e+00    0.0
# Number of Credit Problems     256984.0  1.566284e-01  4.607309e-01    0.0
# Current Credit Balance        256984.0  1.540656e+04  1.966506e+04    0.0
# Bankruptcies                  256455.0  1.103156e-01  3.362287e-01    0.0
# Tax Liens                     256961.0  2.720257e-02  2.459499e-01    0.0
#
#                                   25%      50%      75%         max
# Current Loan Amount            8299.0  14298.0  24367.0  99999999.0
# Credit Score                    714.0    733.0    744.0      7510.0
# Annual Income                 44321.0  61242.0  86462.0   8713547.0
# Years of Credit History          13.5     17.0     21.7        70.5
# Months since last delinquent     16.0     32.0     51.0       176.0
# Number of Open Accounts           8.0     10.0     14.0        76.0
# Number of Credit Problems         0.0      0.0      0.0        11.0
# Current Credit Balance         5974.0  11078.0  19319.0   1731412.0
# Bankruptcies                      0.0      0.0      0.0         7.0
# Tax Liens                         0.0      0.0      0.0        11.0

# %%
df["Loan Status"].value_counts()
# Out:
# Loan Status
# Fully Paid     176191
# Charged Off     80793
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Loan ID                              0
# Customer ID                          0
# Loan Status                          0
# Current Loan Amount                  0
# Term                                 0
# Credit Score                     61676
# Years in current job             11476
# Home Ownership                       0
# Annual Income                    61676
# Purpose                              0
# Monthly Debt                         0
# Years of Credit History              0
# Months since last delinquent    140383
# Number of Open Accounts              0
# Number of Credit Problems            0
# Current Credit Balance               0
# Maximum Open Credit                  0
# Bankruptcies                       529
# Tax Liens                           23
# dtype: int64

# %%
sns.relplot(
    data=df,
    x="Annual Income", y="Current Loan Amount", col="Term",
    hue="Loan Status", style="Loan Status",
)

# %%
plt.figure(figsize=(20,6))
sns.countplot(x= df['Purpose'], hue = df.Term);
plt.xticks(rotation = 45);

# %%
plt.figure(figsize=(20,6))
sns.countplot(x= df['Purpose'], hue = df["Home Ownership"]);
plt.xticks(rotation = 45);

# %%
plt.figure(figsize=(20,6))
sns.countplot(x= df['Years in current job'], hue = df["Loan Status"]);
plt.xticks(rotation = 45);

# %%
plt.figure(figsize=(20,6))
sns.countplot(x= df['Home Ownership'], hue = df["Loan Status"]);
plt.xticks(rotation = 45);

# %%
plt.figure(figsize=(20,6))
sns.countplot(x= df['Purpose'], hue = df["Loan Status"]);
plt.xticks(rotation = 45);

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Annual Income'].dropna(), bins=30, kde=True)
plt.title('Distribution of Credit Score')
plt.show()
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Credit Score'].dropna(), bins=30, kde=True)
plt.title('Distribution of Credit Score')
plt.show()
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Annual Income'].dropna(), bins=30, kde=True)
plt.title('Distribution of Annual Income')
plt.show()
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Home Ownership', y='Annual Income', data=df)
plt.title('Annual Income by Home Ownership')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(y='Purpose', data=df, order = df['Purpose'].value_counts().index)
plt.title('Distribution of Loan Purposes')
plt.show()

# %%
selected_columns = ['Credit Score', 'Annual Income', 'Monthly Debt', 'Years of Credit History']
sns.pairplot(data[selected_columns].dropna())
plt.suptitle('Pair Plot of Selected Features', y=1.02)
plt.show()
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(x='Loan Status', y='Credit Score', data=df)
plt.title('Credit Score Distribution by Loan Status')
plt.show()

# %% [markdown]
# ### Data Manipulation

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 256984 entries, 0 to 256983
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Loan ID                       256984 non-null  object
#  1   Customer ID                   256984 non-null  object
#  2   Loan Status                   256984 non-null  object
#  3   Current Loan Amount           256984 non-null  int64
#  4   Term                          256984 non-null  object
#  5   Credit Score                  195308 non-null  float64
#  6   Years in current job          245508 non-null  object
#  7   Home Ownership                256984 non-null  object
#  8   Annual Income                 195308 non-null  float64
#  9   Purpose                       256984 non-null  object
#  10  Monthly Debt                  256984 non-null  object
#  11  Years of Credit History       256984 non-null  float64
#  12  Months since last delinquent  116601 non-null  float64
#  13  Number of Open Accounts       256984 non-null  int64
#  14  Number of Credit Problems     256984 non-null  int64
#  15  Current Credit Balance        256984 non-null  int64
#  16  Maximum Open Credit           256984 non-null  object
#  17  Bankruptcies                  256455 non-null  float64
#  18  Tax Liens                     256961 non-null  float64
# dtypes: float64(6), int64(4), object(9)
# memory usage: 37.3+ MB

# %%
df.describe().T
# Out:
#                                  count          mean           std    min  \
# Current Loan Amount           256984.0  1.371331e+07  3.438131e+07  505.0
# Credit Score                  195308.0  1.251116e+03  1.762017e+03  585.0
# Annual Income                 195308.0  7.195272e+04  5.887757e+04    0.0
# Years of Credit History       256984.0  1.829019e+01  7.075747e+00    3.4
# Months since last delinquent  116601.0  3.488145e+01  2.185417e+01    0.0
# Number of Open Accounts       256984.0  1.110627e+01  4.982982e+00    0.0
# Number of Credit Problems     256984.0  1.566284e-01  4.607309e-01    0.0
# Current Credit Balance        256984.0  1.540656e+04  1.966506e+04    0.0
# Bankruptcies                  256455.0  1.103156e-01  3.362287e-01    0.0
# Tax Liens                     256961.0  2.720257e-02  2.459499e-01    0.0
#
#                                   25%      50%      75%         max
# Current Loan Amount            8299.0  14298.0  24367.0  99999999.0
# Credit Score                    714.0    733.0    744.0      7510.0
# Annual Income                 44321.0  61242.0  86462.0   8713547.0
# Years of Credit History          13.5     17.0     21.7        70.5
# Months since last delinquent     16.0     32.0     51.0       176.0
# Number of Open Accounts           8.0     10.0     14.0        76.0
# Number of Credit Problems         0.0      0.0      0.0        11.0
# Current Credit Balance         5974.0  11078.0  19319.0   1731412.0
# Bankruptcies                      0.0      0.0      0.0         7.0
# Tax Liens                         0.0      0.0      0.0        11.0

# %%
# convert Maximum Open Credit to Float and correct datas 
df['Maximum Open Credit'].replace('0', 0,inplace=True)
df['Maximum Open Credit'].replace('#VALUE!', np.nan,inplace=True)   
df['Maximum Open Credit'] = df['Maximum Open Credit'].astype(float)

# %%
# divide by 10 to Credit Score values that greater than 1000

df["Credit Score"] = df["Credit Score"].apply(lambda x: x / 10 if x > 1000 else x)

# %%
# fill null values of Tax Liens with 0.0 then convert this column to a int64

df["Tax Liens"].fillna(0.0, inplace=True)
df["Tax Liens"] = df["Tax Liens"].astype(int)

# %%
# fill null values of Bankruptcies with 0.0 then convert this column to a int64

df["Bankruptcies"].fillna(0.0, inplace=True)
df["Bankruptcies"] = df["Bankruptcies"].astype(int)

# %%
# conver '< 1 year' values with 0 in the 'Years in current job' column

df['Years in current job'] = df['Years in current job'].replace('< 1 year', '0', regex=True)

# %%
# remove all nonnumeric values from "Years in current job" column

df['Years in current job'] = df['Years in current job'].str.extract('(\d+)', expand=False).astype(float)

# %%
# remove $ sign from Monthly Dept column

df["Monthly Debt"] = df["Monthly Debt"].str.replace('$', '')

# remove , sign from Monthly Dept column

df["Monthly Debt"] = df["Monthly Debt"].str.replace(',', '')

# remove spaces from beginning of Monthly Dept values and end of monthly depts 

df["Monthly Debt"] = df["Monthly Debt"].str.strip()

# %%
df["Monthly Debt"] = df["Monthly Debt"].astype(float)

# %%
# make null the values that less than 1 of monthly dept column

df["Monthly Debt"] = df["Monthly Debt"].mask(data["Monthly Debt"] < 1, np.nan)

# %%
#replace "other" values of Purpose column with "Other" value

df['Purpose'].replace('other', 'Other',inplace=True)

# %%
df = df.drop(['Loan ID', 'Customer ID'], axis=1)

# %%
#convert 99999999 values in 'Current Loan Amount' to nan values

df["Current Loan Amount"] = df["Current Loan Amount"].replace(99999999, np.nan)

#fill nan values in "Current Loan Amount" with the best approtiate values to predict the most accurate values for loan status

#data["Current Loan Amount"] = data["Current Loan Amount"].fillna(data["Current Loan Amount"].mean())

# %%
# is there any dublicater 

df.duplicated().sum() # drop duplicates # exists
df.drop_duplicates()
# Out:
#         Loan Status  Current Loan Amount        Term  Credit Score  \
# 0        Fully Paid              11520.0  Short Term         741.0
# 1        Fully Paid               3441.0  Short Term         734.0
# 2        Fully Paid              21029.0  Short Term         747.0
# 3        Fully Paid              18743.0  Short Term         747.0
# 4        Fully Paid              11731.0  Short Term         746.0
# ...             ...                  ...         ...           ...
# 256977  Charged Off              11953.0  Short Term         717.0
# 256979   Fully Paid               3911.0  Short Term           NaN
# 256980   Fully Paid               5078.0  Short Term         737.0
# 256981  Charged Off              12116.0  Short Term         746.0
# 256983   Fully Paid              27902.0   Long Term         678.0
#
#         Years in current job Home Ownership  Annual Income  \
# 0                       10.0  Home Mortgage        33694.0
# 1                        4.0  Home Mortgage        42269.0
# 2                       10.0  Home Mortgage        90126.0
# 3                       10.0       Own Home        38072.0
# 4                        4.0           Rent        50025.0
# ...                      ...            ...            ...
# 256977                  10.0  Home Mortgage        39844.0
# 256979                   2.0           Rent            NaN
# 256980                  10.0       Own Home        77186.0
# 256981                   9.0  Home Mortgage        52504.0
# 256983                  10.0  Home Mortgage       117480.0
#
#                    Purpose  Monthly Debt  Years of Credit History  \
# 0       Debt Consolidation        584.03                     12.3
# 1                    Other       1106.04                     26.3
# 2       Debt Consolidation       1321.85                     28.8
# 3       Debt Consolidation        751.92                     26.2
# 4       Debt Consolidation        355.18                     11.5
# ...                    ...           ...                      ...
# 256977  Debt Consolidation        982.82                     11.7
# 256979  Debt Consolidation       1706.58                     19.9
# 256980  Debt Consolidation       1376.47                     19.1
# 256981  Debt Consolidation        297.96                     15.1
# 256983  Debt Consolidation       2525.82                     18.0
#
#         Months since last delinquent  Number of Open Accounts  \
# 0                               41.0                       10
# 1                                NaN                       17
# 2                                NaN                        5
# 3                                NaN                        9
# 4                                NaN                       12
# ...                              ...                      ...
# 256977                           NaN                        9
# 256979                           NaN                       16
# 256980                          47.0                        9
# 256981                          82.0                        8
# 256983                          11.0                       10
#
#         Number of Credit Problems  Current Credit Balance  \
# 0                               0                    6760
# 1                               0                    6262
# 2                               0                   20967
# 3                               0                   22529
# 4                               0                   17391
# ...                           ...                     ...
# 256977                          1                    4176
# 256979                          0                   43992
# 256980                          0                    1717
# 256981                          0                    3315
# 256983                          0                   28317
#
#         Maximum Open Credit  Bankruptcies  Tax Liens
# 0                   16056.0             0          0
# 1                   19149.0             0          0
# 2                   28335.0             0          0
# 3                   43915.0             0          0
# 4                   37081.0             0          0
# ...                     ...           ...        ...
# 256977               4783.0             1          0
# 256979              44080.0             0          0
# 256980               9758.0             0          0
# 256981              20090.0             0          0
# 256983              62371.0             0          0
#
# [231486 rows x 17 columns]

# %%
df.info(), df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 256984 entries, 0 to 256983
# Data columns (total 17 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Loan Status                   256984 non-null  object
#  1   Current Loan Amount           221774 non-null  float64
#  2   Term                          256984 non-null  object
#  3   Credit Score                  195308 non-null  float64
#  4   Years in current job          245508 non-null  float64
#  5   Home Ownership                256984 non-null  object
#  6   Annual Income                 195308 non-null  float64
#  7   Purpose                       256984 non-null  object
#  8   Monthly Debt                  256984 non-null  float64
#  9   Years of Credit History       256984 non-null  float64
#  10  Months since last delinquent  116601 non-null  float64
#  11  Number of Open Accounts       256984 non-null  int64
#  12  Number of Credit Problems     256984 non-null  int64
#  13  Current Credit Balance        256984 non-null  int64
#  14  Maximum Open Credit           256980 non-null  float64
#  15  Bankruptcies                  256984 non-null  int32
#  16  Tax Liens                     256984 non-null  int32
# dtypes: float64(8), int32(2), int64(3), object(4)
# memory usage: 31.4+ MB
# (None,
#  Loan Status                          0
#  Current Loan Amount              35210
#  Term                                 0
#  Credit Score                     61676
#  Years in current job             11476
#  Home Ownership                       0
#  Annual Income                    61676
#  Purpose                              0
#  Monthly Debt                         0
#  Years of Credit History              0
#  Months since last delinquent    140383
#  Number of Open Accounts              0
#  Number of Credit Problems            0
#  Current Credit Balance               0
#  Maximum Open Credit                  4
#  Bankruptcies                         0
#  Tax Liens                            0
#  dtype: int64)

# %%
df.describe().T
# Out:
#                                  count          mean            std    min  \
# Current Loan Amount           221774.0  13979.687389    8260.519207  505.0
# Credit Score                  195308.0    721.203197      27.719518  585.0
# Years in current job          245508.0      5.869401       3.626767    0.0
# Annual Income                 195308.0  71952.716187   58877.574620    0.0
# Monthly Debt                  256984.0    963.310424     634.119410    0.0
# Years of Credit History       256984.0     18.290195       7.075747    3.4
# Months since last delinquent  116601.0     34.881450      21.854165    0.0
# Number of Open Accounts       256984.0     11.106267       4.982982    0.0
# Number of Credit Problems     256984.0      0.156628       0.460731    0.0
# Current Credit Balance        256984.0  15406.556288   19665.057306    0.0
# Maximum Open Credit           256980.0  35723.502599  555007.996978    0.0
# Bankruptcies                  256984.0      0.110089       0.335920    0.0
# Tax Liens                     256984.0      0.027200       0.245939    0.0
#
#                                      25%       50%         75%           max
# Current Loan Amount            7819.0000  12058.00  19438.7500  4.100000e+04
# Credit Score                    710.0000    730.00    741.0000  7.510000e+02
# Years in current job              3.0000      6.00     10.0000  1.000000e+01
# Annual Income                 44321.0000  61242.00  86462.0000  8.713547e+06
# Monthly Debt                    531.9925    844.52   1252.4525  2.293912e+04
# Years of Credit History          13.5000     17.00     21.7000  7.050000e+01
# Months since last delinquent     16.0000     32.00     51.0000  1.760000e+02
# Number of Open Accounts           8.0000     10.00     14.0000  7.600000e+01
# Number of Credit Problems         0.0000      0.00      0.0000  1.100000e+01
# Current Credit Balance         5974.0000  11078.00  19319.0000  1.731412e+06
# Maximum Open Credit           12778.0000  21740.00  36171.2500  1.763322e+08
# Bankruptcies                      0.0000      0.00      0.0000  7.000000e+00
# Tax Liens                         0.0000      0.00      0.0000  1.100000e+01

# %% [markdown]
# ### Filling null values

# %%
df.isnull().sum()
# Out:
# Loan Status                          0
# Current Loan Amount              35210
# Term                                 0
# Credit Score                     61676
# Years in current job             11476
# Home Ownership                       0
# Annual Income                    61676
# Purpose                              0
# Monthly Debt                         0
# Years of Credit History              0
# Months since last delinquent    140383
# Number of Open Accounts              0
# Number of Credit Problems            0
# Current Credit Balance               0
# Maximum Open Credit                  4
# Bankruptcies                         0
# Tax Liens                            0
# dtype: int64

# %%
df["Current Loan Amount"].mean(),df["Current Loan Amount"].std(),df["Current Loan Amount"].max(),df["Current Loan Amount"].min(),df["Current Loan Amount"].median()
# Out:
# (13979.687388963539, 8260.519206804658, 41000.0, 505.0, 12058.0)

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline

def fill_numeric_column(df, target_column, numeric_cols, categorical_cols):
    """
    Fill an empty numeric column in a dataframe using linear regression.

    Args:
        df (pandas.DataFrame): The input dataframe.
        target_column (str): The name of the empty numeric column to be filled.
        numeric_cols (list): The list of numeric columns in the dataframe.
        categorical_cols (list): The list of categorical columns in the dataframe.

    Returns:
        pandas.DataFrame: The updated dataframe with the target column filled.
    """
    # Create a list of columns without the target column
    cols_without_target = [col for col in df.columns if col != target_column]

    # Fill numeric columns with mean
    for col in numeric_cols:
        df[col] = df[col].fillna(df[col].mean())

    # Fill categorical columns with mode and encode
    for col in categorical_cols:
        df[col] = df[col].fillna(df[col].mode()[0])
        le = LabelEncoder()
        df[col] = le.fit_transform(df[col])

    # Split the dataframe into training and test sets based on the target column
    train_df = df[df[target_column].notna()]
    test_df = df[df[target_column].isna()]

    X_train = train_df[cols_without_target]
    y_train = train_df[target_column]
    X_test = test_df[cols_without_target]

    # Create a pipeline with an imputer and the LinearRegression estimator
    imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
    model = Pipeline([('imputer', imputer), ('regressor', LinearRegression())])

    # Fit the model
    model.fit(X_train, y_train)

    # Predict the values for the test set
    y_pred = model.predict(X_test)
    df.loc[df[target_column].isna(), target_column] = y_pred

    # Combine the training and test sets
    df_filled = pd.concat([df[~df[target_column].isna()], df[df[target_column].isna()]], ignore_index=True)

    return df_filled

# %%
categorical_cols = ['Loan Status', 'Term', 'Home Ownership', 'Purpose']
numeric_cols = df.columns.drop(categorical_cols).drop(['Annual Income', 'Credit Score', 'Current Loan Amount', 'Years in current job'])

df1 = fill_numeric_column(df, 'Annual Income', numeric_cols, categorical_cols)
df2 = fill_numeric_column(df1, 'Credit Score', numeric_cols, categorical_cols)
df3 = fill_numeric_column(df2, 'Current Loan Amount', numeric_cols, categorical_cols)

# %%
df3.isnull().sum()
# Out:
# Loan Status                         0
# Current Loan Amount                 0
# Term                                0
# Credit Score                        0
# Years in current job            11476
# Home Ownership                      0
# Annual Income                       0
# Purpose                             0
# Monthly Debt                        0
# Years of Credit History             0
# Months since last delinquent        0
# Number of Open Accounts             0
# Number of Credit Problems           0
# Current Credit Balance              0
# Maximum Open Credit                 0
# Bankruptcies                        0
# Tax Liens                           0
# dtype: int64

# %%
# drop Years in current job from df3

#df3 = df3.drop('Years in current job', axis=1)
df3.info()
df3.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 256984 entries, 0 to 256983
# Data columns (total 16 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Loan Status                   256984 non-null  int64
#  1   Current Loan Amount           256984 non-null  float64
#  2   Term                          256984 non-null  int64
#  3   Credit Score                  256984 non-null  float64
#  4   Home Ownership                256984 non-null  int64
#  5   Annual Income                 256984 non-null  float64
#  6   Purpose                       256984 non-null  int64
#  7   Monthly Debt                  256984 non-null  float64
#  8   Years of Credit History       256984 non-null  float64
#  9   Months since last delinquent  256984 non-null  float64
#  10  Number of Open Accounts       256984 non-null  int64
#  11  Number of Credit Problems     256984 non-null  int64
#  12  Current Credit Balance        256984 non-null  int64
#  13  Maximum Open Credit           256984 non-null  float64
#  14  Bankruptcies                  256984 non-null  int32
#  15  Tax Liens                     256984 non-null  int32
# dtypes: float64(7), int32(2), int64(7)
# memory usage: 29.4 MB
# Loan Status                     0
# Current Loan Amount             0
# Term                            0
# Credit Score                    0
# Home Ownership                  0
# Annual Income                   0
# Purpose                         0
# Monthly Debt                    0
# Years of Credit History         0
# Months since last delinquent    0
# Number of Open Accounts         0
# Number of Credit Problems       0
# Current Credit Balance          0
# Maximum Open Credit             0
# Bankruptcies                    0
# Tax Liens                       0
# dtype: int64

# %%
df3.describe().T
# Out:
#                                  count          mean            std  \
# Loan Status                   256984.0      0.685611       0.464273
# Current Loan Amount           256984.0  13926.437288    7900.217446
# Term                          256984.0      0.749588       0.433251
# Credit Score                  256984.0    721.203255      25.301876
# Home Ownership                256984.0      1.935346       0.955680
# Annual Income                 256984.0  71942.428975   53506.734103
# Purpose                       256984.0      3.474033       1.397663
# Monthly Debt                  256984.0    963.310424     634.119410
# Years of Credit History       256984.0     18.290195       7.075747
# Months since last delinquent  256984.0     34.881450      14.720796
# Number of Open Accounts       256984.0     11.106267       4.982982
# Number of Credit Problems     256984.0      0.156628       0.460731
# Current Credit Balance        256984.0  15406.556288   19665.057306
# Maximum Open Credit           256984.0  35723.502599  555003.677547
# Bankruptcies                  256984.0      0.110089       0.335920
# Tax Liens                     256984.0      0.027200       0.245939
#
#                                       min          25%          50%  \
# Loan Status                      0.000000      0.00000      1.00000
# Current Loan Amount          -1208.442224   8100.00000  12112.00000
# Term                             0.000000      0.00000      1.00000
# Credit Score                   585.000000    710.00000    729.00000
# Home Ownership                   0.000000      1.00000      2.00000
# Annual Income                    0.000000  45671.00000  62950.00000
# Purpose                          0.000000      3.00000      3.00000
# Monthly Debt                     0.000000    531.99250    844.52000
# Years of Credit History          3.400000     13.50000     17.00000
# Months since last delinquent     0.000000     34.88145     34.88145
# Number of Open Accounts          0.000000      8.00000     10.00000
# Number of Credit Problems        0.000000      0.00000      0.00000
# Current Credit Balance           0.000000   5974.00000  11078.00000
# Maximum Open Credit              0.000000  12778.00000  21740.00000
# Bankruptcies                     0.000000      0.00000      0.00000
# Tax Liens                        0.000000      0.00000      0.00000
#
#                                       75%           max
# Loan Status                       1.00000  1.000000e+00
# Current Loan Amount           18533.36647  1.930573e+05
# Term                              1.00000  1.000000e+00
# Credit Score                    739.00000  7.610339e+02
# Home Ownership                    3.00000  3.000000e+00
# Annual Income                 86552.64582  8.713547e+06
# Purpose                           3.00000  8.000000e+00
# Monthly Debt                   1252.45250  2.293912e+04
# Years of Credit History          21.70000  7.050000e+01
# Months since last delinquent     34.88145  1.760000e+02
# Number of Open Accounts          14.00000  7.600000e+01
# Number of Credit Problems         0.00000  1.100000e+01
# Current Credit Balance        19319.00000  1.731412e+06
# Maximum Open Credit           36171.00000  1.763322e+08
# Bankruptcies                      0.00000  7.000000e+00
# Tax Liens                         0.00000  1.100000e+01

# %%
abs(df3.corr(numeric_only=True)["Loan Status"]).sort_values(ascending=False)
# Out:
# Loan Status                     1.000000
# Credit Score                    0.293871
# Term                            0.183811
# Annual Income                   0.075055
# Current Loan Amount             0.069975
# Home Ownership                  0.067860
# Years of Credit History         0.035548
# Number of Open Accounts         0.020787
# Monthly Debt                    0.016609
# Months since last delinquent    0.015952
# Tax Liens                       0.012590
# Purpose                         0.012297
# Number of Credit Problems       0.010179
# Current Credit Balance          0.008838
# Maximum Open Credit             0.007921
# Bankruptcies                    0.001107
# Name: Loan Status, dtype: float64

# %%
x = df3.drop("Loan Status", axis=1)  
y = df3[['Loan Status']]

# %%
x = pd.get_dummies(x, columns=['Term', 'Home Ownership','Purpose'], drop_first=True)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import BernoulliNB
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier


def algo_test(x,y):
        #Bütün modelleri tanımlıyorum
        gnb=GaussianNB()
        bnb=BernoulliNB()
        lr=LogisticRegression()
        dt=DecisionTreeClassifier()
        rf=RandomForestClassifier()
        gbc=GradientBoostingClassifier()
        knc=KNeighborsClassifier()
        

       
        
        algos=[gnb,bnb,lr,dt,rf,gbc,knc]
        algo_names=['GaussianNB','BernoulliNB','LogisticRegression','DecisionTreeClassifier','RandomForestClassifier','GradientBoostingClassifier','KNeighborsClassifier']
        
        x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=.20,random_state=42)
        
        confusion_matrixes= []
        classification_reports= []
        accuracy_scores=[]        
        
        for algo in algos:
            p=algo.fit(x_train,y_train).predict(x_test)
            classification_reports.append(classification_report(p , y_test))
            confusion_matrixes.append(confusion_matrix(p , y_test))
            accuracy_scores.append(accuracy_score(p , y_test))

        for i in range(len(algo_names)):
            print('Algorithm:'+ '\n' , algo_names[i])
            print('Confusion Matrix:'+ '\n' , confusion_matrixes[i])
            print('Classification Report: '+ '\n' , classification_reports[i])
            print('Accuracy Score:'+ '\n' , accuracy_scores[i])
            print('************************************************************')

# %%
algo_test(x,y)
# Out:
# Algorithm:
#  GaussianNB
# Confusion Matrix:
#  [[14614 25279]
#  [ 1547  9957]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.37      0.52     39893
#            1       0.28      0.87      0.43     11504
#
#     accuracy                           0.48     51397
#    macro avg       0.59      0.62      0.47     51397
# weighted avg       0.77      0.48      0.50     51397
#
# Accuracy Score:
#  0.4780629219604257
# ************************************************************
# Algorithm:
#  BernoulliNB
# Confusion Matrix:
#  [[  229   221]
#  [15932 35015]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.01      0.51      0.03       450
#            1       0.99      0.69      0.81     50947
#
#     accuracy                           0.69     51397
#    macro avg       0.50      0.60      0.42     51397
# weighted avg       0.99      0.69      0.81     51397
#
# Accuracy Score:
#  0.6857209564760589
# ************************************************************
# Algorithm:
#  LogisticRegression
# Confusion Matrix:
#  [[  565   482]
#  [15596 34754]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.03      0.54      0.07      1047
#            1       0.99      0.69      0.81     50350
#
#     accuracy                           0.69     51397
#    macro avg       0.51      0.61      0.44     51397
# weighted avg       0.97      0.69      0.80     51397
#
# Accuracy Score:
#  0.6871801856139463
# ************************************************************
# Algorithm:
#  DecisionTreeClassifier
# Confusion Matrix:
#  [[12559  6422]
#  [ 3602 28814]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.78      0.66      0.71     18981
#            1       0.82      0.89      0.85     32416
#
#     accuracy                           0.80     51397
#    macro avg       0.80      0.78      0.78     51397
# weighted avg       0.80      0.80      0.80     51397
#
# Accuracy Score:
#  0.8049691616242193
# ************************************************************
# Algorithm:
#  RandomForestClassifier
# Confusion Matrix:
#  [[12370  2568]
#  [ 3791 32668]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.77      0.83      0.80     14938
#            1       0.93      0.90      0.91     36459
#
#     accuracy                           0.88     51397
#    macro avg       0.85      0.86      0.85     51397
# weighted avg       0.88      0.88      0.88     51397
#
# Accuracy Score:
#  0.8762768254956514
# ************************************************************
# Algorithm:
#  GradientBoostingClassifier
# Confusion Matrix:
#  [[ 6890  4054]
#  [ 9271 31182]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.43      0.63      0.51     10944
#            1       0.88      0.77      0.82     40453
#
#     accuracy                           0.74     51397
#    macro avg       0.66      0.70      0.67     51397
# weighted avg       0.79      0.74      0.76     51397
#
# Accuracy Score:
#  0.7407436231686675
# ************************************************************
# Algorithm:
#  KNeighborsClassifier
# Confusion Matrix:
#  [[ 6087  6771]
#  [10074 28465]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.38      0.47      0.42     12858
#            1       0.81      0.74      0.77     38539
#
#     accuracy                           0.67     51397
#    macro avg       0.59      0.61      0.60     51397
# weighted avg       0.70      0.67      0.68     51397
#
# Accuracy Score:
#  0.6722571356304843
# ************************************************************

# %%
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=.20,random_state=42)

# %%
rf=RandomForestClassifier()
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
pred = rf.predict(x_test)

# %%
accuracy_score(pred, y_test)
# Out:
# 0.8777944237990544

# %%
confusion_matrix(pred, y_test)
# Out:
# array([[12391,  2511],
#        [ 3770, 32725]], dtype=int64)

# %%
sns.heatmap(confusion_matrix(pred , y_test), annot=True)
# Out:
# <Axes: >

# %%
print(classification_report(pred , y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.83      0.80     14902
#            1       0.93      0.90      0.91     36495
#
#     accuracy                           0.88     51397
#    macro avg       0.85      0.86      0.86     51397
# weighted avg       0.88      0.88      0.88     51397

# %% [markdown]
# According to the RandomForest classifier %88 of the predictions are counted as accurate.
