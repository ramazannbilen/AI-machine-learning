# %% [markdown]
# # NER - Named Entity Recognition

# %% [markdown]
# Bir yazının içinde geçen yer, kişi, org isimleri tespit etme

# %%
from textblob import TextBlob

# %%
sent = '''
Zafer loves natural language processing and artificial intelligence.
Turkish Space Agency TUA is natioanl space agency of Turkey.

'''

# %%
TextBlob(sent).sentiment.polarity
# Out:
# -0.25

# %% [markdown]
# NLP - translate
# Lang Detect
# POS - PArt of Speech
# Sentiment
# Text Classification
# Text Generation
# Text Summarization
# NER
# Topic Modelling

# %%
#!pip install -U spacy

# %%
import spacy
from spacy import displacy

# %%
NER = spacy.load("en_core_web_sm")

# %%
text = """
Zafer Acar loves NLP and artificial intelligence -. Python is a great programming language.
The Turkish Space Agency TUA is natioanl space agency of Turkey, headquartered in Ankara.
It operates under the Department of Space which is directly overseen
by the President of Turkey and administer of TUA is Serdar Hüseyin Yıldırım."""

# %%
text1 = NER(text)

# %%
for word in text1.ents:
    print(word.text, word.label_)
# Out:
# Zafer Acar PERSON
# NLP ORG
# The Turkish Space Agency ORG
# TUA ORG
# Turkey GPE
# Ankara GPE
# the Department of Space ORG
# Turkey GPE
# TUA ORG
# Serdar Hüseyin Yıldırım PERSON

# %%
spacy.explain("PERSON")
# Out:
# 'People, including fictional'

# %%
spacy.explain("ORG")
# Out:
# 'Companies, agencies, institutions, etc.'

# %%
spacy.explain("GPE")
# Out:
# 'Countries, cities, states'

# %%
displacy.render(text1)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="f1b3d3e1cc3b43a1ac73d3f3396cadc1-0" class="displacy" width="9675" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">Zafer</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
# ...

# %%
displacy.render(text1, style="ent",jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"><br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Zafer Acar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  loves
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NLP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and artificial intelligence -. Python is a great programming language.<br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Turkish Space Agency
# ...
